# %%
import networkx as nx
G = nx.Graph()
G.add_node('a')
nodes_to_add = ['b', 'c', 'd']
G.add_nodes_from(nodes_to_add)
G.add_edge('a', 'b')
edges_to_add = [('a', 'c'), ('b', 'c'), ('c', 'd')]
G.add_edges_from(edges_to_add)
nx.draw(G, with_labels=True)

# %%
nx.draw(G,
        with_labels=True,
        node_color='red',
        node_size=1200,
        font_color='white',
        font_size=16,
        )

# %%
G.nodes()
# Out:
# NodeView(('a', 'b', 'c', 'd'))

# %%
G.edges()
# Out:
# EdgeView([('a', 'b'), ('a', 'c'), ('b', 'c'), ('c', 'd')])

# %%
for node in G.nodes:
    print(node)
# Out:
# a
# b
# c
# d

# %%
for edge in G.edges:
    print(edge)
# Out:
# ('a', 'b')
# ('a', 'c')
# ('b', 'c')
# ('c', 'd')

# %%
G.number_of_nodes()
# Out:
# 4

# %%
G.neighbors('b')

# %%
for neighbor in G.neighbors('b'):
    print(neighbor)
# Out:
# a
# c

# %%
nx.is_tree(G)
# Out:
# False

# %%
nx.is_connected(G)
# Out:
# True

# %%
G.has_node('a')
# Out:
# True

# %%
G.has_node('g')
# Out:
# False

# %%
G.has_edge('a', 'b')
# Out:
# True

# %%
G.has_edge('k', 's')
# Out:
# False

# %%
len(list(G.neighbors('a')))
# Out:
# 2

# %%
def get_leaves(G):
# Out:
#   File "C:\Users\KERONA~1\AppData\Local\Temp/ipykernel_10188/1482567287.py", line 3
#
#     ^
# IndentationError: expected an indented block

# %%
def get_leaves(G):
# Out:
#   File "C:\Users\KERONA~1\AppData\Local\Temp/ipykernel_10188/3952839917.py", line 1
#     def get_leaves(G):
#                       ^
# IndentationError: expected an indented block

# %%
items = ['spider', 'y', 'banana']
[item.upper() for item in items]
# Out:
# ['SPIDER', 'Y', 'BANANA']

# %%
print(G.nodes())
print([G.degree(n) for n in G.nodes()])
# Out:
# ['a', 'b', 'c', 'd']
# [2, 2, 3, 1]

# %%
G = nx.Graph()

G.add_nodes_from(['cat','dog','virus',13])

G.add_edge('cat','dog')

nx.draw(G, with_labels=True, font_color='red', node_size=1000)

# %%
D = nx.DiGraph()

D.add_edges_from([(1,2),(2,3),(3,2),(3,4),(3,5),(4,5),(4,6),(5,6),(6,4),(4,2)])

nx.draw(D, with_labels=True)

# %%
print('Successors of 2:', list(D.successors(2)))

print('Predecessors of 2:', list(D.predecessors(2)))
# Out:
# Successors of 2: [3]
# Predecessors of 2: [1, 3, 4]
