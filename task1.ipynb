# %%
print("welcome kerolos")
# Out:
# welcome kerolos

# %%
print('welcome kerolos')
# Out:
# welcome kerolos

# %%
mystr='hello'
mynum=16
print(mystr)
print(mynum)
# Out:
# hello
# 16

# %%
mystr='hello'
mynum=16
mystr=10
print(mystr)
print(mynum)
# Out:
# 10
# 16

# %%
mystr
# Out:
# 10

# %%
mystr
mynum
# Out:
# 16

# %%
mynum
mystr
# Out:
# 10

# %%
print(mystr)
print(mynum)
# Out:
# 10
# 16

# %%
numofapples= 5
if numofapples<1:
    print('You have no apples')
elif numofapples==1:
     print('You have one apple')
elif numofapples<4:
      print('You have afew apple')
else:
     print('You have many apple')
# Out:
# You have many apple

# %%
numofapples= 3
if numofapples<1:
    print('You have no apples')
elif numofapples==1:
     print('You have one apple')
elif numofapples<4:
      print('You have afew apple')
else:
     print('You have many apple')
# Out:
# You have afew apple

# %%
mylist=['Alice', 'Bob', 'Carol', 'Dave']
print(mylist[1])
# Out:
# Bob

# %%
mylist[0]
# Out:
# 'Alice'

# %%
mylist[-1]
# Out:
# 'Dave'

# %%
mylist[0:2]
# Out:
# ['Alice', 'Bob']

# %%
mylist[1:3]
# Out:
# ['Bob', 'Carol']

# %%
mylist[2:]
# Out:
# ['Carol', 'Dave']

# %%
mylist[:2]
# Out:
# ['Alice', 'Bob']

# %%
mylist.append('last item')
mylist
# Out:
# ['Alice', 'Bob', 'Carol', 'Dave', 'last item']

# %%
mylist.insert(2,'between')
mylist
# Out:
# ['Alice', 'Bob', 'between', 'Carol', 'Dave', 'last item']

# %%
del mylist[2]
mylist
# Out:
# ['Alice', 'Bob', 'Carol', 'Dave', 'last item']

# %%
del mylist[-1]
mylist
# Out:
# ['Alice', 'Bob', 'Carol', 'Dave']

# %%
mylist.insert(2,'repeat')
mylist.append('repeat')
mylist
# Out:
# ['Alice', 'Bob', 'repeat', 'Carol', 'Dave', 'repeat']

# %%
del mylist[2]

# %%
mylist
# Out:
# ['Alice', 'Bob', 'Carol', 'Dave', 'repeat']

# %%
for mylist in st_name:
    print('welcome'+st_name+'!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10268/332746402.py in <module>
# ----> 1 for mylist in st_name:
#       2     print('welcome'+st_name+'!')
#
# NameError: name 'st_name' is not defined

# %%
for st_name in mylist:
    print('welcome '+ st_name+'!')
# Out:
# welcomeAlice!
# welcomeBob!
# welcomeCarol!
# welcomeDave!
# welcomerepeat!

# %%
for st_name in mylist:
    print('welcome '+ st_name+'!')
# Out:
# welcome Alice!
# welcome Bob!
# welcome Carol!
# welcome Dave!
# welcome repeat!

# %%
long=[]
for st_name in mylist:
    if len(st_name)>4:
        long.append(st_name)
long
# Out:
# ['Alice', 'Carol', 'repeat']

# %%
print(len(mylist[0]))
# Out:
# 5

# %%
for st_name in mylist:
    print(len(st_name))
# Out:
# 5
# 3
# 5
# 4
# 6

# %%
print(len(mylist))
# Out:
# 5

# %%
print(len(mylist[1]))
# Out:
# 3

# %%
mylist=['Alice', 'Bob', 'Carol', 'Dave']
newlist=[]
for st_name0 in mylist:
    for st_name1 in mylist:
        newlist.append((st_name0,st_name1)
        )
newlist
# Out:
# [('Alice', 'Alice'),
#  ('Alice', 'Bob'),
#  ('Alice', 'Carol'),
#  ('Alice', 'Dave'),
#  ('Bob', 'Alice'),
#  ('Bob', 'Bob'),
#  ('Bob', 'Carol'),
#  ('Bob', 'Dave'),
#  ('Carol', 'Alice'),
#  ('Carol', 'Bob'),
#  ('Carol', 'Carol'),
#  ('Carol', 'Dave'),
#  ('Dave', 'Alice'),
#  ('Dave', 'Bob'),
#  ('Dave', 'Carol'),
#  ('Dave', 'Dave')]

# %%
mylist=['Alice', 'Bob', 'Carol', 'Dave']
newlist=[]
for st_name0 in mylist:
    for st_name1 in mylist:
        if st_name1==st_name0:
            print(st_name0)
        else:    
            newlist.append((st_name0,st_name1)
        )
newlist
# Out:
# Alice
# Bob
# Carol
# Dave
# [('Alice', 'Bob'),
#  ('Alice', 'Carol'),
#  ('Alice', 'Dave'),
#  ('Bob', 'Alice'),
#  ('Bob', 'Carol'),
#  ('Bob', 'Dave'),
#  ('Carol', 'Alice'),
#  ('Carol', 'Bob'),
#  ('Carol', 'Dave'),
#  ('Dave', 'Alice'),
#  ('Dave', 'Bob'),
#  ('Dave', 'Carol')]

# %%
mylist=['Alice', 'Bob', 'Carol', 'Dave']
newlist=[]
for st_name0 in mylist:
    for st_name1 in mylist:
        if st_name1!=st_name0:
              
            newlist.append((st_name0,st_name1)
        )
newlist
# Out:
# [('Alice', 'Bob'),
#  ('Alice', 'Carol'),
#  ('Alice', 'Dave'),
#  ('Bob', 'Alice'),
#  ('Bob', 'Carol'),
#  ('Bob', 'Dave'),
#  ('Carol', 'Alice'),
#  ('Carol', 'Bob'),
#  ('Carol', 'Dave'),
#  ('Dave', 'Alice'),
#  ('Dave', 'Bob'),
#  ('Dave', 'Carol')]

# %%
mylist.append('kerolos nady')

# %%
mylist
# Out:
# ['Alice', 'Bob', 'Carol', 'Dave', 'kerolos nady']

# %%
mytuple=('Alice', 'Bob', 'Carol')
mytuple[1]
# Out:
# 'Bob'

# %%
mytuple.append('kero')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10268/488058385.py in <module>
# ----> 1 mytuple.append('kero')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
del mytuple[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10268/3670622312.py in <module>
# ----> 1 del mytuple[1]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
kero1,kero2,kero3=mytuple
print(kero1)
print(kero2)
print(kero3)
# Out:
# Alice
# Bob
# Carol

# %%
kero1,kero3=mytuple
print(kero1)
print(kero3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10268/1573474496.py in <module>
# ----> 1 kero1,kero3=mytuple
#       2 print(kero1)
#       3 print(kero3)
#
# ValueError: too many values to unpack (expected 2)

# %%
student_grades = [
    ('Alice', 'Spanish', 'A'),
    ('Bob', 'French', 'C'),
    ('Carol', 'Italian', 'B+'),
    ('Dave', 'Italian', 'A-'),
]
for st_name,subj,st_grade in student_grades:
    if st_grade.startswith('A'):
        print('congra ' + st_name +' because you getting '+ st_grade +' in ' +subj)
# Out:
# congra Alice because you getting A in Spanish
# congra Dave because you getting A- in Italian

# %%
student_grades = [
    ('Alice', 'Spanish', 'A'),
    ('Bob', 'French', 'C'),
    ('Carol', 'Italian', 'B+'),
    ('Dave', 'Italian', 'A-'),
]
for st_name,subj,st_grade in student_grades:
    if st_grade=='A':
        print('congra ' + st_name +' because you getting '+ st_grade +' in ' +subj)
# Out:
# congra Alice because you getting A in Spanish

# %%
nationality={
    'kero':'Egyptian',
     'Bob': 'French',
    'Carol': 'Italian',
    'Dave': 'Italian',
}

# %%
nationality['kero']
# Out:
# 'Egyptian'

# %%
nationality['kero33']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10268/1182642395.py in <module>
# ----> 1 nationality['kero33']
#
# KeyError: 'kero33'

# %%
'kero33' in nationality
# Out:
# False

# %%
'Dave' in nationality
# Out:
# True

# %%
nationality['bebo']='French'
nationality
# Out:
# {'kero': 'Egyptian',
#  'Bob': 'French',
#  'Carol': 'Italian',
#  'Dave': 'Italian',
#  'bebo': 'French'}

# %%
del nationality['Carol']
nationality
# Out:
# {'kero': 'Egyptian', 'Bob': 'French', 'Dave': 'Italian', 'bebo': 'French'}

# %%
for key in nationality :
    value=nationality[key]
    print('te key is ' + key + 'the value is ' + value)
# Out:
# te key is kerothe value is Egyptian
# te key is Bobthe value is French
# te key is Davethe value is Italian
# te key is bebothe value is French

# %%
for key,value in nationality.items():
    print('te key is ' + key + 'the value is ' + value)
# Out:
# te key is kerothe value is Egyptian
# te key is Bobthe value is French
# te key is Davethe value is Italian
# te key is bebothe value is French

# %%
student_grades = [
    ('Alice', 'Spanish', 'A'),
    ('Bob', 'French', 'C'),
    ('Carol', 'Italian', 'B+'),
    ('Dave', 'Italian', 'A-'),
]

# %%
student_grades[1]
# Out:
# ('Bob', 'French', 'C')

# %%
student_grades[1][2]
# Out:
# 'C'

# %%
student_grade_records = []
for student_name, subject, grade in student_grades:
    record = {
        'name': student_name,
        'subject': subject,
        'grade': grade,
    }
    student_grade_records.append(record)
    
student_grade_records
# Out:
# [{'name': 'Alice', 'subject': 'Spanish', 'grade': 'A'},
#  {'name': 'Bob', 'subject': 'French', 'grade': 'C'},
#  {'name': 'Carol', 'subject': 'Italian', 'grade': 'B+'},
#  {'name': 'Dave', 'subject': 'Italian', 'grade': 'A-'}]
